# %%
#installing packages to read pingouin
# !pip install pingouin


#Import standard libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
import pingouin
from scipy.stats import chi2_contingency
import matplotlib.colors as mcolors
import statsmodels.formula.api as sm
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
Michigan_LinReg = pd.read_csv('data by state/michigan.csv')

# %% [markdown]
# # Boyfriend/Girlfriend

# %%
#BF = boyfriend, GF = girlfriend
#perform multiple linear regression using boyfriend_girlfriend relationship (violent crimes category) as the primary metric against the 5 search terms
BF_GF_vs_Search_Terms0 = 'boyfriend_girlfriend ~ abuse + handgun + rape + domestic_violence'


#abuse + handgun + rape + domestic_violence

BF_GF_model0 = sm.ols(formula = BF_GF_vs_Search_Terms0, data = Michigan_LinReg)
BF_GF_fitted0 = BF_GF_model0.fit()
print(BF_GF_fitted0.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.414
# Model:                              OLS   Adj. R-squared:                  0.233
# Method:                   Least Squares   F-statistic:                     2.292
# Date:                  Wed, 11 Jan 2023   Prob (F-statistic):              0.115
# Time:                          01:03:03   Log-Likelihood:                -158.49
# No. Observations:                    18   AIC:                             327.0
# Df Residuals:                        13   BIC:                             331.4
# Df Model:                             4
# Covariance Type:              nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          2.744e+04   4633.932      5.923      0.000    1.74e+04    3.75e+04
# ...

# %%
#BF = boyfriend, GF = girlfriend
#perform multiple linear regression using boyfriend_girlfriend relationship (violent crimes category) as the primary metric against the 5 search terms
BF_GF_vs_Search_Terms1 = 'boyfriend_girlfriend ~ abuse + handgun + rape'


#abuse + handgun + rape + domestic_violence

BF_GF_model1 = sm.ols(formula = BF_GF_vs_Search_Terms1, data = Michigan_LinReg)
BF_GF_fitted1 = BF_GF_model1.fit()
print(BF_GF_fitted1.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.409
# Model:                              OLS   Adj. R-squared:                  0.282
# Method:                   Least Squares   F-statistic:                     3.226
# Date:                  Wed, 11 Jan 2023   Prob (F-statistic):             0.0550
# Time:                          01:03:34   Log-Likelihood:                -158.56
# No. Observations:                    18   AIC:                             325.1
# Df Residuals:                        14   BIC:                             328.7
# Df Model:                             3
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.668e+04   3877.580      6.881      0.000    1.84e+04     3.5e+04
# ...

# %%
#BF = boyfriend, GF = girlfriend
#perform multiple linear regression using boyfriend_girlfriend relationship (violent crimes category) as the primary metric against the 5 search terms
BF_GF_vs_Search_Terms2 = 'boyfriend_girlfriend ~ abuse + handgun'


#abuse + handgun + rape + domestic_violence

BF_GF_model2 = sm.ols(formula = BF_GF_vs_Search_Terms2, data = Michigan_LinReg)
BF_GF_fitted2 = BF_GF_model2.fit()
print(BF_GF_fitted2.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.179
# Model:                              OLS   Adj. R-squared:                  0.069
# Method:                   Least Squares   F-statistic:                     1.630
# Date:                  Wed, 11 Jan 2023   Prob (F-statistic):              0.229
# Time:                          01:03:58   Log-Likelihood:                -161.52
# No. Observations:                    18   AIC:                             329.0
# Df Residuals:                        15   BIC:                             331.7
# Df Model:                             2
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.929e+04   4228.991      6.925      0.000    2.03e+04    3.83e+04
# ...

# %%
#BF = boyfriend, GF = girlfriend
#perform multiple linear regression using boyfriend_girlfriend relationship (violent crimes category) as the primary metric against the 5 search terms
BF_GF_vs_Search_Terms3 = 'boyfriend_girlfriend ~ abuse'


#abuse + handgun + rape + domestic_violence

BF_GF_model3 = sm.ols(formula = BF_GF_vs_Search_Terms3, data = Michigan_LinReg)
BF_GF_fitted3 = BF_GF_model3.fit()
print(BF_GF_fitted3.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.076
# Model:                              OLS   Adj. R-squared:                  0.018
# Method:                   Least Squares   F-statistic:                     1.311
# Date:                  Wed, 11 Jan 2023   Prob (F-statistic):              0.269
# Time:                          01:04:25   Log-Likelihood:                -162.58
# No. Observations:                    18   AIC:                             329.2
# Df Residuals:                        16   BIC:                             330.9
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.418e+04   2060.392     11.738      0.000    1.98e+04    2.86e+04
# ...

# %%
#BF = boyfriend, GF = girlfriend
#perform multiple linear regression using boyfriend_girlfriend relationship (violent crimes category) as the primary metric against the 5 search terms
BF_GF_vs_Search_Terms4 = 'boyfriend_girlfriend ~ handgun'


#abuse + handgun + rape + domestic_violence

BF_GF_model4 = sm.ols(formula = BF_GF_vs_Search_Terms4, data = Michigan_LinReg)
BF_GF_fitted4 = BF_GF_model4.fit()
print(BF_GF_fitted4.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.101
# Model:                              OLS   Adj. R-squared:                  0.045
# Method:                   Least Squares   F-statistic:                     1.806
# Date:                  Wed, 11 Jan 2023   Prob (F-statistic):              0.198
# Time:                          01:05:07   Log-Likelihood:                -162.33
# No. Observations:                    18   AIC:                             328.7
# Df Residuals:                        16   BIC:                             330.4
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.694e+04   3787.384      7.114      0.000    1.89e+04     3.5e+04
# ...

# %%
#BF = boyfriend, GF = girlfriend
#perform multiple linear regression using boyfriend_girlfriend relationship (violent crimes category) as the primary metric against the 5 search terms
BF_GF_vs_Search_Terms5 = 'boyfriend_girlfriend ~ rape'


#abuse + handgun + rape + domestic_violence

BF_GF_model5 = sm.ols(formula = BF_GF_vs_Search_Terms5, data = Michigan_LinReg)
BF_GF_fitted5 = BF_GF_model5.fit()
print(BF_GF_fitted5.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.402
# Model:                              OLS   Adj. R-squared:                  0.364
# Method:                   Least Squares   F-statistic:                     10.75
# Date:                  Wed, 11 Jan 2023   Prob (F-statistic):            0.00473
# Time:                          01:06:01   Log-Likelihood:                -158.66
# No. Observations:                    18   AIC:                             321.3
# Df Residuals:                        16   BIC:                             323.1
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.795e+04   1891.180     14.781      0.000    2.39e+04     3.2e+04
# ...

# %%
#BF = boyfriend, GF = girlfriend
#perform multiple linear regression using boyfriend_girlfriend relationship (violent crimes category) as the primary metric against the 5 search terms
BF_GF_vs_Search_Terms6 = 'boyfriend_girlfriend ~ domestic_violence'


#abuse + handgun + rape + domestic_violence

BF_GF_model6 = sm.ols(formula = BF_GF_vs_Search_Terms6, data = Michigan_LinReg)
BF_GF_fitted6 = BF_GF_model6.fit()
print(BF_GF_fitted6.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.061
# Model:                              OLS   Adj. R-squared:                  0.003
# Method:                   Least Squares   F-statistic:                     1.043
# Date:                  Wed, 11 Jan 2023   Prob (F-statistic):              0.322
# Time:                          01:06:47   Log-Likelihood:                -162.72
# No. Observations:                    18   AIC:                             329.4
# Df Residuals:                        16   BIC:                             331.2
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          2.555e+04   3613.511      7.071      0.000    1.79e+04    3.32e+04
# ...

# %% [markdown]
# # Homosexual

# %%
#HR=homosexual relationship. 
#perform multiple linear regression using homosexual relationship (violent crimes category) as the primary metric against the 5 search terms
HR_vs_Search_Terms0 = 'homosexual_relationship ~ abuse + handgun + rape + domestic_violence'

HR_model0 = sm.ols(formula = HR_vs_Search_Terms0, data = Michigan_LinReg)
HR_fitted0 = HR_model0.fit()
print(HR_fitted0.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.550
# Model:                                 OLS   Adj. R-squared:                  0.412
# Method:                      Least Squares   F-statistic:                     3.975
# Date:                     Wed, 11 Jan 2023   Prob (F-statistic):             0.0254
# Time:                             01:07:28   Log-Likelihood:                -121.32
# No. Observations:                       18   AIC:                             252.6
# Df Residuals:                           13   BIC:                             257.1
# Df Model:                                4
# Covariance Type:                 nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
#HR=homosexual relationship. 
#perform multiple linear regression using homosexual relationship (violent crimes category) as the primary metric against the 5 search terms
HR_vs_Search_Terms1 = 'homosexual_relationship ~ abuse + handgun + rape'

HR_model1 = sm.ols(formula = HR_vs_Search_Terms1, data = Michigan_LinReg)
HR_fitted1 = HR_model1.fit()
print(HR_fitted1.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.540
# Model:                                 OLS   Adj. R-squared:                  0.442
# Method:                      Least Squares   F-statistic:                     5.486
# Date:                     Wed, 11 Jan 2023   Prob (F-statistic):             0.0105
# Time:                             01:07:55   Log-Likelihood:                -121.52
# No. Observations:                       18   AIC:                             251.0
# Df Residuals:                           14   BIC:                             254.6
# Df Model:                                3
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      9.8980    495.201      0.020      0.984   -1052.204    1072.000
# ...

# %%
#HR=homosexual relationship. 
#perform multiple linear regression using homosexual relationship (violent crimes category) as the primary metric against the 5 search terms
HR_vs_Search_Terms2 = 'homosexual_relationship ~ abuse + handgun'

HR_model2 = sm.ols(formula = HR_vs_Search_Terms2, data = Michigan_LinReg)
HR_fitted2 = HR_model2.fit()
print(HR_fitted2.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.196
# Model:                                 OLS   Adj. R-squared:                  0.089
# Method:                      Least Squares   F-statistic:                     1.833
# Date:                     Wed, 11 Jan 2023   Prob (F-statistic):              0.194
# Time:                             01:08:19   Log-Likelihood:                -126.54
# No. Observations:                       18   AIC:                             259.1
# Df Residuals:                           15   BIC:                             261.8
# Df Model:                                2
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -451.0405    605.821     -0.745      0.468   -1742.317     840.236
# ...

# %%
#HR=homosexual relationship. 
#perform multiple linear regression using homosexual relationship (violent crimes category) as the primary metric against the 5 search terms
HR_vs_Search_Terms3 = 'homosexual_relationship ~ abuse'

HR_model3 = sm.ols(formula = HR_vs_Search_Terms3, data = Michigan_LinReg)
HR_fitted3 = HR_model3.fit()
print(HR_fitted3.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.004
# Model:                                 OLS   Adj. R-squared:                 -0.058
# Method:                      Least Squares   F-statistic:                   0.06118
# Date:                     Wed, 11 Jan 2023   Prob (F-statistic):              0.808
# Time:                             01:08:43   Log-Likelihood:                -128.48
# No. Observations:                       18   AIC:                             261.0
# Df Residuals:                           16   BIC:                             262.7
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    560.2192    309.812      1.808      0.089     -96.552    1216.990
# ...

# %%
#HR=homosexual relationship. 
#perform multiple linear regression using homosexual relationship (violent crimes category) as the primary metric against the 5 search terms
HR_vs_Search_Terms4 = 'homosexual_relationship ~ handgun'

HR_model4 = sm.ols(formula = HR_vs_Search_Terms4, data = Michigan_LinReg)
HR_fitted4 = HR_model4.fit()
print(HR_fitted4.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.192
# Model:                                 OLS   Adj. R-squared:                  0.142
# Method:                      Least Squares   F-statistic:                     3.806
# Date:                     Wed, 11 Jan 2023   Prob (F-statistic):             0.0688
# Time:                             01:09:30   Log-Likelihood:                -126.59
# No. Observations:                       18   AIC:                             257.2
# Df Residuals:                           16   BIC:                             259.0
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -371.3802    520.125     -0.714      0.486   -1473.997     731.236
# ...

# %%
#HR=homosexual relationship. 
#perform multiple linear regression using homosexual relationship (violent crimes category) as the primary metric against the 5 search terms
HR_vs_Search_Terms5 = 'homosexual_relationship ~ rape'

HR_model5 = sm.ols(formula = HR_vs_Search_Terms5, data = Michigan_LinReg)
HR_fitted5 = HR_model5.fit()
print(HR_fitted5.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.442
# Model:                                 OLS   Adj. R-squared:                  0.407
# Method:                      Least Squares   F-statistic:                     12.67
# Date:                     Wed, 11 Jan 2023   Prob (F-statistic):            0.00261
# Time:                             01:10:04   Log-Likelihood:                -123.26
# No. Observations:                       18   AIC:                             250.5
# Df Residuals:                           16   BIC:                             252.3
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -285.1608    264.575     -1.078      0.297    -846.035     275.714
# ...

# %%
#HR=homosexual relationship. 
#perform multiple linear regression using homosexual relationship (violent crimes category) as the primary metric against the 5 search terms
HR_vs_Search_Terms6 = 'homosexual_relationship ~ domestic_violence'

HR_model6 = sm.ols(formula = HR_vs_Search_Terms6, data = Michigan_LinReg)
HR_fitted6 = HR_model6.fit()
print(HR_fitted6.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.011
# Model:                                 OLS   Adj. R-squared:                 -0.051
# Method:                      Least Squares   F-statistic:                    0.1785
# Date:                     Wed, 11 Jan 2023   Prob (F-statistic):              0.678
# Time:                             01:10:44   Log-Likelihood:                -128.41
# No. Observations:                       18   AIC:                             260.8
# Df Residuals:                           16   BIC:                             262.6
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Spouse

# %%
#perform multiple linear regression using spouse relationship (violent crimes category) as the primary metric against the 5 search terms
Spouse_vs_Search_Terms0 = 'spouse ~ abuse + handgun + rape + domestic_violence'

#abuse + handgun + rape + domestic_violence

Spouse_model0 = sm.ols(formula = Spouse_vs_Search_Terms0, data = Michigan_LinReg)
Spouse_fitted0 = Spouse_model0.fit()
print(Spouse_fitted0.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.861
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     20.10
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):           1.79e-05
# Time:                        00:52:05   Log-Likelihood:                -143.17
# No. Observations:                  18   AIC:                             296.3
# Df Residuals:                      13   BIC:                             300.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          8692.8642   1978.876      4.393      0.001    4417.763     1.3e+04
# ...

# %%
#perform multiple linear regression using spouse relationship (violent crimes category) as the primary metric against the 5 search terms
Spouse_vs_Search_Terms1 = 'spouse ~ abuse + handgun + rape'

#abuse + handgun + rape + domestic_violence

Spouse_model1 = sm.ols(formula = Spouse_vs_Search_Terms1, data = Michigan_LinReg)
Spouse_fitted1 = Spouse_model1.fit()
print(Spouse_fitted1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.840
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     24.47
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):           7.89e-06
# Time:                        00:52:39   Log-Likelihood:                -144.43
# No. Observations:                  18   AIC:                             296.9
# Df Residuals:                      14   BIC:                             300.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7301.3839   1769.125      4.127      0.001    3506.988    1.11e+04
# ...

# %%
#perform multiple linear regression using spouse relationship (violent crimes category) as the primary metric against the 5 search terms
Spouse_vs_Search_Terms2 = 'spouse ~ abuse + handgun'

#abuse + handgun + rape + domestic_violence

Spouse_model2 = sm.ols(formula = Spouse_vs_Search_Terms2, data = Michigan_LinReg)
Spouse_fitted2 = Spouse_model2.fit()
print(Spouse_fitted2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.815
# Model:                            OLS   Adj. R-squared:                  0.791
# Method:                 Least Squares   F-statistic:                     33.10
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):           3.16e-06
# Time:                        00:53:10   Log-Likelihood:                -145.72
# No. Observations:                  18   AIC:                             297.4
# Df Residuals:                      15   BIC:                             300.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   8046.6557   1757.883      4.577      0.000    4299.817    1.18e+04
# ...

# %%
#perform multiple linear regression using spouse relationship (violent crimes category) as the primary metric against the 5 search terms
Spouse_vs_Search_Terms3 = 'spouse ~ abuse'

#abuse + handgun + rape + domestic_violence

Spouse_model3 = sm.ols(formula = Spouse_vs_Search_Terms3, data = Michigan_LinReg)
Spouse_fitted3 = Spouse_model3.fit()
print(Spouse_fitted3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.750
# Method:                 Least Squares   F-statistic:                     52.11
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):           2.05e-06
# Time:                        00:53:35   Log-Likelihood:                -147.88
# No. Observations:                  18   AIC:                             299.8
# Df Residuals:                      16   BIC:                             301.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4922.5421    910.498      5.406      0.000    2992.374    6852.711
# ...

# %%
#perform multiple linear regression using spouse relationship (violent crimes category) as the primary metric against the 5 search terms
Spouse_vs_Search_Terms4 = 'spouse ~ handgun'

#abuse + handgun + rape + domestic_violence

Spouse_model4 = sm.ols(formula = Spouse_vs_Search_Terms4, data = Michigan_LinReg)
Spouse_fitted4 = Spouse_model4.fit()
print(Spouse_fitted4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.9017
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):              0.356
# Time:                        00:54:25   Log-Likelihood:                -160.42
# No. Observations:                  18   AIC:                             324.8
# Df Residuals:                      16   BIC:                             326.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    1.45e+04   3407.422      4.256      0.001    7277.341    2.17e+04
# ...

# %%
#perform multiple linear regression using spouse relationship (violent crimes category) as the primary metric against the 5 search terms
Spouse_vs_Search_Terms5 = 'spouse ~ rape'

#abuse + handgun + rape + domestic_violence

Spouse_model5 = sm.ols(formula = Spouse_vs_Search_Terms5, data = Michigan_LinReg)
Spouse_fitted5 = Spouse_model5.fit()
print(Spouse_fitted5.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                 -0.018
# Method:                 Least Squares   F-statistic:                    0.7029
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):              0.414
# Time:                        00:55:07   Log-Likelihood:                -160.53
# No. Observations:                  18   AIC:                             325.1
# Df Residuals:                      16   BIC:                             326.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9575.9164   2097.734      4.565      0.000    5128.919     1.4e+04
# ...

# %%
#perform multiple linear regression using spouse relationship (violent crimes category) as the primary metric against the 5 search terms
Spouse_vs_Search_Terms6 = 'spouse ~ domestic_violence'

#abuse + handgun + rape + domestic_violence

Spouse_model6 = sm.ols(formula = Spouse_vs_Search_Terms6, data = Michigan_LinReg)
Spouse_fitted6 = Spouse_model6.fit()
print(Spouse_fitted6.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.323
# Model:                            OLS   Adj. R-squared:                  0.281
# Method:                 Least Squares   F-statistic:                     7.651
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):             0.0138
# Time:                        00:55:51   Log-Likelihood:                -157.40
# No. Observations:                  18   AIC:                             318.8
# Df Residuals:                      16   BIC:                             320.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          3930.9002   2688.678      1.462      0.163   -1768.842    9630.642
# ...

# %% [markdown]
# # Ex-spouse

# %%
#perform multiple linear regression using ex-spouse relationship (violent crimes category) as the primary metric against the 5 search terms
Ex_spouse_vs_Search_Terms0 = 'ex_spouse ~ abuse + handgun + rape + domestic_violence'

Ex_spouse_model0 = sm.ols(formula = Ex_spouse_vs_Search_Terms0, data = Michigan_LinReg)
Ex_spouse_fitted0 = Ex_spouse_model0.fit()
print(Ex_spouse_fitted0.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.615
# Model:                            OLS   Adj. R-squared:                  0.497
# Method:                 Least Squares   F-statistic:                     5.196
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):             0.0101
# Time:                        00:57:56   Log-Likelihood:                -116.91
# No. Observations:                  18   AIC:                             243.8
# Df Residuals:                      13   BIC:                             248.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          1682.0101    459.999      3.657      0.003     688.243    2675.778
# ...

# %%
#perform multiple linear regression using ex-spouse relationship (violent crimes category) as the primary metric against the 5 search terms
Ex_spouse_vs_Search_Terms1 = 'ex_spouse ~ abuse + handgun + rape'

Ex_spouse_model1 = sm.ols(formula = Ex_spouse_vs_Search_Terms1, data = Michigan_LinReg)
Ex_spouse_fitted1 = Ex_spouse_model1.fit()
print(Ex_spouse_fitted1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.527
# Model:                            OLS   Adj. R-squared:                  0.426
# Method:                 Least Squares   F-statistic:                     5.204
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):             0.0127
# Time:                        00:58:26   Log-Likelihood:                -118.76
# No. Observations:                  18   AIC:                             245.5
# Df Residuals:                      14   BIC:                             249.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1283.8759    424.898      3.022      0.009     372.561    2195.191
# ...

# %%
#perform multiple linear regression using ex-spouse relationship (violent crimes category) as the primary metric against the 5 search terms
Ex_spouse_vs_Search_Terms2 = 'ex_spouse ~ abuse + handgun'

Ex_spouse_model2 = sm.ols(formula = Ex_spouse_vs_Search_Terms2, data = Michigan_LinReg)
Ex_spouse_fitted2 = Ex_spouse_model2.fit()
print(Ex_spouse_fitted2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.327
# Method:                 Least Squares   F-statistic:                     5.132
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):             0.0200
# Time:                        00:58:59   Log-Likelihood:                -120.81
# No. Observations:                  18   AIC:                             247.6
# Df Residuals:                      15   BIC:                             250.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1515.1867    440.591      3.439      0.004     576.089    2454.284
# ...

# %%
#perform multiple linear regression using ex-spouse relationship (violent crimes category) as the primary metric against the 5 search terms
Ex_spouse_vs_Search_Terms3 = 'ex_spouse ~ abuse'

Ex_spouse_model3 = sm.ols(formula = Ex_spouse_vs_Search_Terms3, data = Michigan_LinReg)
Ex_spouse_fitted3 = Ex_spouse_model3.fit()
print(Ex_spouse_fitted3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.361
# Model:                            OLS   Adj. R-squared:                  0.321
# Method:                 Least Squares   F-statistic:                     9.039
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):            0.00836
# Time:                        00:59:27   Log-Likelihood:                -121.47
# No. Observations:                  18   AIC:                             246.9
# Df Residuals:                      16   BIC:                             248.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1100.5117    209.932      5.242      0.000     655.476    1545.548
# ...

# %%
#perform multiple linear regression using ex-spouse relationship (violent crimes category) as the primary metric against the 5 search terms
Ex_spouse_vs_Search_Terms4 = 'ex_spouse ~ handgun'

Ex_spouse_model4 = sm.ols(formula = Ex_spouse_vs_Search_Terms4, data = Michigan_LinReg)
Ex_spouse_fitted4 = Ex_spouse_model4.fit()
print(Ex_spouse_fitted4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.047
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.7943
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):              0.386
# Time:                        01:00:18   Log-Likelihood:                -125.07
# No. Observations:                  18   AIC:                             254.1
# Df Residuals:                      16   BIC:                             255.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2134.5207    477.894      4.467      0.000    1121.431    3147.611
# ...

# %%
#perform multiple linear regression using ex-spouse relationship (violent crimes category) as the primary metric against the 5 search terms
Ex_spouse_vs_Search_Terms5 = 'ex_spouse ~ rape'

Ex_spouse_model5 = sm.ols(formula = Ex_spouse_vs_Search_Terms5, data = Michigan_LinReg)
Ex_spouse_fitted5 = Ex_spouse_model5.fit()
print(Ex_spouse_fitted5.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.060
# Method:                 Least Squares   F-statistic:                   0.04082
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):              0.842
# Time:                        01:01:06   Log-Likelihood:                -125.48
# No. Observations:                  18   AIC:                             255.0
# Df Residuals:                      16   BIC:                             256.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1771.3750    299.264      5.919      0.000    1136.964    2405.786
# ...

# %%
#perform multiple linear regression using ex-spouse relationship (violent crimes category) as the primary metric against the 5 search terms
Ex_spouse_vs_Search_Terms6 = 'ex_spouse ~ domestic_violence'

Ex_spouse_model6 = sm.ols(formula = Ex_spouse_vs_Search_Terms6, data = Michigan_LinReg)
Ex_spouse_fitted6 = Ex_spouse_model6.fit()
print(Ex_spouse_fitted6.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.076
# Model:                            OLS   Adj. R-squared:                  0.018
# Method:                 Least Squares   F-statistic:                     1.310
# Date:                Wed, 11 Jan 2023   Prob (F-statistic):              0.269
# Time:                        01:01:46   Log-Likelihood:                -124.79
# No. Observations:                  18   AIC:                             253.6
# Df Residuals:                      16   BIC:                             255.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          1214.4475    439.373      2.764      0.014     283.018    2145.877
# ...

# %%
#perform multiple linear regression using domestic_violence (search term) as the primary metric against the 4 violent crimes relationships

# %%
#perform multiple linear regression using handgun (search term) as the primary metric against the 4 violent crimes relationships

# %%
#perform multiple linear regression using rape (search term) as the primary metric against the 4 violent crimes relationships

# %%
#perform multiple linear regression using abuse (search term) as the primary metric against the 4 violent crimes relationships

# %%
#perform multiple linear regression using sexual_violence (search term) as the primary metric against the 4 violent crimes relationships

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=dbf2a01f-3e99-4593-9faf-0399a8afaf03' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
