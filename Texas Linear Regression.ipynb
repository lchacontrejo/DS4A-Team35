# %% [markdown]
# ## Texas Linear Regression

# %%
#installing packages to read pingouin
# !pip install pingouin


#Import standard libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
import pingouin
from scipy.stats import chi2_contingency
import matplotlib.colors as mcolors
import statsmodels.formula.api as sm
import statsmodels.api as sm1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 KB 10.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 68.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.1/973.1 KB 83.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 KB 52.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 58.4 MB/s eta 0:00:00
# ...
#   Created wheel for pingouin: filename=pingouin-0.5.3-py3-none-any.whl size=198588 sha256=ccb64b7335c7dcbd5c2e50d9ca43da9aa9ba825a8973dfc878856b6873328c61
#   Stored in directory: /root/.cache/pip/wheels/17/f5/28/d3f6d4af74be0693f3e8994af3acbf53fe4efb48615cbbdda1
# ...

# %%
# TEXAS LINEAR REGRESSION


#read in texas data
texas = pd.read_csv('data by state/texas.csv')

# %% [markdown]
# ## Homosexual Relationships

# %%
#linear regression using homosexual from FBI Crime Data & Google Search Terms
tx_homosexual_relationship_reg0 = ' homosexual_relationship ~ abuse + handgun + rape + domestic_violence'

# abuse + handgun + rape + domestic_violence
#model output
tx_homosexual_model0 = sm.ols(formula = tx_homosexual_relationship_reg0, data = texas)
tx_homosexual_model_fit0 = tx_homosexual_model0.fit()
print(tx_homosexual_model_fit0.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.317
# Model:                                 OLS   Adj. R-squared:                  0.107
# Method:                      Least Squares   F-statistic:                     1.510
# Date:                     Tue, 24 Jan 2023   Prob (F-statistic):              0.256
# Time:                             18:05:04   Log-Likelihood:                -116.96
# No. Observations:                       18   AIC:                             243.9
# Df Residuals:                           13   BIC:                             248.4
# Df Model:                                4
# Covariance Type:                 nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
#linear regression using homosexual from FBI Crime Data & Google Search Terms
tx_homosexual_relationship_reg1 = ' homosexual_relationship ~ abuse + handgun + rape'

# abuse + handgun + rape + domestic_violence
#model output

tx_homosexual_model1 = sm.ols(formula = tx_homosexual_relationship_reg1, data = texas)
tx_homosexual_model_fit1 = tx_homosexual_model1.fit()
print(tx_homosexual_model_fit1.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.114
# Model:                                 OLS   Adj. R-squared:                 -0.076
# Method:                      Least Squares   F-statistic:                    0.5996
# Date:                     Tue, 24 Jan 2023   Prob (F-statistic):              0.626
# Time:                             18:05:04   Log-Likelihood:                -119.31
# No. Observations:                       18   AIC:                             246.6
# Df Residuals:                           14   BIC:                             250.2
# Df Model:                                3
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    646.5834    292.414      2.211      0.044      19.419    1273.748
# ...

# %%
#linear regression using homosexual from FBI Crime Data & Google Search Terms
tx_homosexual_relationship_reg2 = ' homosexual_relationship ~ abuse + handgun'

# abuse + handgun + rape + domestic_violence
#model output
tx_homosexual_model2 = sm.ols(formula = tx_homosexual_relationship_reg2, data = texas)
tx_homosexual_model_fit2 = tx_homosexual_model2.fit()
print(tx_homosexual_model_fit2.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.113
# Model:                                 OLS   Adj. R-squared:                 -0.005
# Method:                      Least Squares   F-statistic:                    0.9584
# Date:                     Tue, 24 Jan 2023   Prob (F-statistic):              0.406
# Time:                             18:05:04   Log-Likelihood:                -119.31
# No. Observations:                       18   AIC:                             244.6
# Df Residuals:                           15   BIC:                             247.3
# Df Model:                                2
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    658.5079    253.982      2.593      0.020     117.159    1199.857
# ...

# %%
#linear regression using homosexual from FBI Crime Data & Google Search Terms
tx_homosexual_relationship_reg3 = ' homosexual_relationship ~ abuse'

# abuse + handgun + rape + domestic_violence
#model output
tx_homosexual_model3 = sm.ols(formula = tx_homosexual_relationship_reg3, data = texas)
tx_homosexual_model_fit3 = tx_homosexual_model3.fit()
print(tx_homosexual_model_fit3.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.085
# Model:                                 OLS   Adj. R-squared:                  0.028
# Method:                      Least Squares   F-statistic:                     1.486
# Date:                     Tue, 24 Jan 2023   Prob (F-statistic):              0.241
# Time:                             18:05:04   Log-Likelihood:                -119.59
# No. Observations:                       18   AIC:                             243.2
# Df Residuals:                           16   BIC:                             245.0
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    574.4333    219.416      2.618      0.019     109.291    1039.575
# ...

# %%
#linear regression using homosexual from FBI Crime Data & Google Search Terms
tx_homosexual_relationship_reg4 = ' homosexual_relationship ~ handgun'

# abuse + handgun + rape + domestic_violence
#model output
tx_homosexual_model4 = sm.ols(formula = tx_homosexual_relationship_reg4, data = texas)
tx_homosexual_model_fit4 = tx_homosexual_model4.fit()
print(tx_homosexual_model_fit4.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.090
# Model:                                 OLS   Adj. R-squared:                  0.033
# Method:                      Least Squares   F-statistic:                     1.583
# Date:                     Tue, 24 Jan 2023   Prob (F-statistic):              0.226
# Time:                             18:05:04   Log-Likelihood:                -119.54
# No. Observations:                       18   AIC:                             243.1
# Df Residuals:                           16   BIC:                             244.9
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    585.4462    221.370      2.645      0.018     116.163    1054.729
# ...

# %%
#linear regression using homosexual from FBI Crime Data & Google Search Terms
tx_homosexual_relationship_reg5 = ' homosexual_relationship ~ rape'

# abuse + handgun + rape + domestic_violence
#model output
tx_homosexual_model5 = sm.ols(formula = tx_homosexual_relationship_reg5, data = texas)
tx_homosexual_model_fit5 = tx_homosexual_model5.fit()
print(tx_homosexual_model_fit5.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.022
# Model:                                 OLS   Adj. R-squared:                 -0.039
# Method:                      Least Squares   F-statistic:                    0.3573
# Date:                     Tue, 24 Jan 2023   Prob (F-statistic):              0.558
# Time:                             18:05:04   Log-Likelihood:                -120.20
# No. Observations:                       18   AIC:                             244.4
# Df Residuals:                           16   BIC:                             246.2
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    450.9685    235.666      1.914      0.074     -48.620     950.557
# ...

# %%
#linear regression using homosexual from FBI Crime Data & Google Search Terms
tx_homosexual_relationship_reg6 = ' homosexual_relationship ~ domestic_violence'

# abuse + handgun + rape + domestic_violence
#model output
tx_homosexual_model6 = sm.ols(formula = tx_homosexual_relationship_reg6, data = texas)
tx_homosexual_model_fit6 = tx_homosexual_model6.fit()
print(tx_homosexual_model_fit6.summary())
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.176
# Model:                                 OLS   Adj. R-squared:                  0.124
# Method:                      Least Squares   F-statistic:                     3.415
# Date:                     Tue, 24 Jan 2023   Prob (F-statistic):             0.0832
# Time:                             18:05:04   Log-Likelihood:                -118.65
# No. Observations:                       18   AIC:                             241.3
# Df Residuals:                           16   BIC:                             243.1
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...

# %% [markdown]
# # Relationship

# %%
#linear regression using relationship status from FBI Crime & Google Search Terms
tx_relationship_reg0 = 'boyfriend_girlfriend ~ abuse + handgun + rape + domestic_violence'
#abuse + handgun + rape + domestic_violence

#model output
tx_relationship_model0 = sm.ols(formula = tx_relationship_reg0, data = texas)
tx_relationship_model_fit0 = tx_relationship_model0.fit()
print(tx_relationship_model_fit0.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.786
# Model:                              OLS   Adj. R-squared:                  0.720
# Method:                   Least Squares   F-statistic:                     11.91
# Date:                  Tue, 24 Jan 2023   Prob (F-statistic):           0.000274
# Time:                          18:05:04   Log-Likelihood:                -191.77
# No. Observations:                    18   AIC:                             393.5
# Df Residuals:                        13   BIC:                             398.0
# Df Model:                             4
# Covariance Type:              nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          1.591e+05   2.93e+04      5.428      0.000    9.58e+04    2.22e+05
# ...

# %%
#linear regression using relationship status from FBI Crime & Google Search Terms
tx_relationship_reg1 = 'boyfriend_girlfriend ~ abuse + handgun + rape'
#abuse + handgun + rape + domestic_violence

#model output
tx_relationship_model1 = sm.ols(formula = tx_relationship_reg1, data = texas)
tx_relationship_model_fit1 = tx_relationship_model1.fit()
print(tx_relationship_model_fit1.summary())
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.762
# Model:                              OLS   Adj. R-squared:                  0.711
# Method:                   Least Squares   F-statistic:                     14.91
# Date:                  Tue, 24 Jan 2023   Prob (F-statistic):           0.000122
# Time:                          18:05:04   Log-Likelihood:                -192.73
# No. Observations:                    18   AIC:                             393.5
# Df Residuals:                        14   BIC:                             397.0
# Df Model:                             3
# Covariance Type:              nonrobust
# ...

# %%
#linear regression using relationship status from FBI Crime & Google Search Terms
tx_relationship_reg2 = 'boyfriend_girlfriend ~ abuse + handgun'
#abuse + handgun + rape + domestic_violence

#model output
tx_relationship_model2 = sm.ols(formula = tx_relationship_reg2, data = texas)
tx_relationship_model_fit2 = tx_relationship_model2.fit()
print(tx_relationship_model_fit2.summary())
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.550
# Model:                              OLS   Adj. R-squared:                  0.490
# Method:                   Least Squares   F-statistic:                     9.182
# Date:                  Tue, 24 Jan 2023   Prob (F-statistic):            0.00249
# Time:                          18:05:04   Log-Likelihood:                -198.44
# No. Observations:                    18   AIC:                             402.9
# Df Residuals:                        15   BIC:                             405.6
# Df Model:                             2
# Covariance Type:              nonrobust
# ...

# %%
#linear regression using relationship status from FBI Crime & Google Search Terms
tx_relationship_reg3 = 'boyfriend_girlfriend ~ abuse'
#abuse + handgun + rape + domestic_violence

#model output
tx_relationship_model3 = sm.ols(formula = tx_relationship_reg3, data = texas)
tx_relationship_model_fit3 = tx_relationship_model3.fit()
print(tx_relationship_model_fit3.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.298
# Model:                              OLS   Adj. R-squared:                  0.254
# Method:                   Least Squares   F-statistic:                     6.783
# Date:                  Tue, 24 Jan 2023   Prob (F-statistic):             0.0192
# Time:                          18:05:04   Log-Likelihood:                -202.45
# No. Observations:                    18   AIC:                             408.9
# Df Residuals:                        16   BIC:                             410.7
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     7.5e+04   2.19e+04      3.425      0.003    2.86e+04    1.21e+05
# ...

# %%
#linear regression using relationship status from FBI Crime & Google Search Terms
tx_relationship_reg4 = 'boyfriend_girlfriend ~ handgun'
#abuse + handgun + rape + domestic_violence

#model output
tx_relationship_model4 = sm.ols(formula = tx_relationship_reg4, data = texas)
tx_relationship_model_fit4 = tx_relationship_model4.fit()
print(tx_relationship_model_fit4.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.517
# Model:                              OLS   Adj. R-squared:                  0.487
# Method:                   Least Squares   F-statistic:                     17.12
# Date:                  Tue, 24 Jan 2023   Prob (F-statistic):           0.000774
# Time:                          18:05:04   Log-Likelihood:                -199.09
# No. Observations:                    18   AIC:                             402.2
# Df Residuals:                        16   BIC:                             404.0
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    9.36e+04   1.84e+04      5.094      0.000    5.46e+04    1.33e+05
# ...

# %%
#linear regression using relationship status from FBI Crime & Google Search Terms
tx_relationship_reg5 = 'boyfriend_girlfriend ~ rape'
#abuse + handgun + rape + domestic_violence

#model output
tx_relationship_model5 = sm.ols(formula = tx_relationship_reg5, data = texas)
tx_relationship_model_fit5 = tx_relationship_model5.fit()
print(tx_relationship_model_fit5.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.611
# Model:                              OLS   Adj. R-squared:                  0.587
# Method:                   Least Squares   F-statistic:                     25.14
# Date:                  Tue, 24 Jan 2023   Prob (F-statistic):           0.000127
# Time:                          18:05:04   Log-Likelihood:                -197.13
# No. Observations:                    18   AIC:                             398.3
# Df Residuals:                        16   BIC:                             400.1
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.024e+05   1.69e+04      6.046      0.000    6.65e+04    1.38e+05
# ...

# %%
#linear regression using relationship status from FBI Crime & Google Search Terms
tx_relationship_reg6 = 'boyfriend_girlfriend ~ domestic_violence'
#abuse + handgun + rape + domestic_violence

#model output
tx_relationship_model6 = sm.ols(formula = tx_relationship_reg6, data = texas)
tx_relationship_model_fit6 = tx_relationship_model6.fit()
print(tx_relationship_model_fit6.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.018
# Model:                              OLS   Adj. R-squared:                 -0.043
# Method:                   Least Squares   F-statistic:                    0.2983
# Date:                  Tue, 24 Jan 2023   Prob (F-statistic):              0.592
# Time:                          18:05:04   Log-Likelihood:                -205.47
# No. Observations:                    18   AIC:                             414.9
# Df Residuals:                        16   BIC:                             416.7
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          4.318e+04   4.41e+04      0.978      0.342   -5.04e+04    1.37e+05
# ...

# %% [markdown]
# # Exspouse

# %%
#linear regression using ex-spouse from FBI Crime & Google Search Terms
tx_exspouse_reg0 = ' ex_spouse ~ abuse + handgun + rape + domestic_violence'

#abuse + handgun + rape + domestic_violence

#model output
tx_exspouse_model0 = sm.ols(formula = tx_exspouse_reg0, data = texas)
tx_exspouse_model_fit0 = tx_exspouse_model0.fit()
print(tx_exspouse_model_fit0.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.713
# Method:                 Least Squares   F-statistic:                     11.53
# Date:                Tue, 24 Jan 2023   Prob (F-statistic):           0.000321
# Time:                        18:05:05   Log-Likelihood:                -154.83
# No. Observations:                  18   AIC:                             319.7
# Df Residuals:                      13   BIC:                             324.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          2.048e+04   3763.823      5.441      0.000    1.23e+04    2.86e+04
# ...

# %%
#linear regression using ex-spouse from FBI Crime & Google Search Terms
tx_exspouse_reg1 = ' ex_spouse ~ abuse + handgun + rape'

#abuse + handgun + rape + domestic_violence

#model output
tx_exspouse_model1 = sm.ols(formula = tx_exspouse_reg1, data = texas)
tx_exspouse_model_fit1 = tx_exspouse_model1.fit()
print(tx_exspouse_model_fit1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.697
# Method:                 Least Squares   F-statistic:                     14.04
# Date:                Tue, 24 Jan 2023   Prob (F-statistic):           0.000167
# Time:                        18:05:05   Log-Likelihood:                -155.97
# No. Observations:                  18   AIC:                             319.9
# Df Residuals:                      14   BIC:                             323.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.642e+04   2241.215      7.327      0.000    1.16e+04    2.12e+04
# ...

# %%
#linear regression using ex-spouse from FBI Crime & Google Search Terms
tx_exspouse_reg2 = ' ex_spouse ~ abuse + handgun'

#abuse + handgun + rape + domestic_violence

#model output
tx_exspouse_model2 = sm.ols(formula = tx_exspouse_reg2, data = texas)
tx_exspouse_model_fit2 = tx_exspouse_model2.fit()
print(tx_exspouse_model_fit2.summary())
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.498
# Model:                            OLS   Adj. R-squared:                  0.431
# Method:                 Least Squares   F-statistic:                     7.449
# Date:                Tue, 24 Jan 2023   Prob (F-statistic):            0.00567
# Time:                        18:05:05   Log-Likelihood:                -162.25
# No. Observations:                  18   AIC:                             330.5
# Df Residuals:                      15   BIC:                             333.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %%
#linear regression using ex-spouse from FBI Crime & Google Search Terms
tx_exspouse_reg3 = ' ex_spouse ~ abuse'

#abuse + handgun + rape + domestic_violence

#model output
tx_exspouse_model3 = sm.ols(formula = tx_exspouse_reg3, data = texas)
tx_exspouse_model_fit3 = tx_exspouse_model3.fit()
print(tx_exspouse_model_fit3.summary())
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.250
# Model:                            OLS   Adj. R-squared:                  0.203
# Method:                 Least Squares   F-statistic:                     5.324
# Date:                Tue, 24 Jan 2023   Prob (F-statistic):             0.0347
# Time:                        18:05:05   Log-Likelihood:                -165.88
# No. Observations:                  18   AIC:                             335.8
# Df Residuals:                      16   BIC:                             337.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
#linear regression using ex-spouse from FBI Crime & Google Search Terms
tx_exspouse_reg4 = ' ex_spouse ~ handgun'

#abuse + handgun + rape + domestic_violence

#model output
tx_exspouse_model4 = sm.ols(formula = tx_exspouse_reg4, data = texas)
tx_exspouse_model_fit4 = tx_exspouse_model4.fit()
print(tx_exspouse_model_fit4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.477
# Model:                            OLS   Adj. R-squared:                  0.444
# Method:                 Least Squares   F-statistic:                     14.58
# Date:                Tue, 24 Jan 2023   Prob (F-statistic):            0.00151
# Time:                        18:05:05   Log-Likelihood:                -162.63
# No. Observations:                  18   AIC:                             329.3
# Df Residuals:                      16   BIC:                             331.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.171e+04   2424.972      4.828      0.000    6567.173    1.68e+04
# ...

# %%
#linear regression using ex-spouse from FBI Crime & Google Search Terms
tx_exspouse_reg5 = ' ex_spouse ~ rape'

#abuse + handgun + rape + domestic_violence

#model output
tx_exspouse_model5 = sm.ols(formula = tx_exspouse_reg5, data = texas)
tx_exspouse_model_fit5 = tx_exspouse_model5.fit()
print(tx_exspouse_model_fit5.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.642
# Model:                            OLS   Adj. R-squared:                  0.619
# Method:                 Least Squares   F-statistic:                     28.66
# Date:                Tue, 24 Jan 2023   Prob (F-statistic):           6.46e-05
# Time:                        18:05:05   Log-Likelihood:                -159.22
# No. Observations:                  18   AIC:                             322.4
# Df Residuals:                      16   BIC:                             324.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.345e+04   2060.226      6.530      0.000    9085.233    1.78e+04
# ...

# %%
#linear regression using ex-spouse from FBI Crime & Google Search Terms
tx_exspouse_reg6 = ' ex_spouse ~ domestic_violence'

#abuse + handgun + rape + domestic_violence

#model output
tx_exspouse_model6 = sm.ols(formula = tx_exspouse_reg6, data = texas)
tx_exspouse_model_fit6 = tx_exspouse_model6.fit()
print(tx_exspouse_model_fit6.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                 -0.038
# Method:                 Least Squares   F-statistic:                    0.3701
# Date:                Tue, 24 Jan 2023   Prob (F-statistic):              0.551
# Time:                        18:05:05   Log-Likelihood:                -168.26
# No. Observations:                  18   AIC:                             340.5
# Df Residuals:                      16   BIC:                             342.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          6025.0575   5583.725      1.079      0.297   -5811.910    1.79e+04
# ...

# %% [markdown]
# # Spouse

# %%
#linear regression using spouse from FBI Crime & Google Search Terms
tx_spouse_reg0 = 'spouse ~ abuse + handgun + rape+ domestic_violence'

#abuse + handgun + rape + domestic_violence

#model output
tx_spouse_model0 = sm.ols(formula = tx_spouse_reg0, data = texas)
tx_spouse_model_fit0 = tx_spouse_model0.fit()
print(tx_spouse_model_fit0.summary())
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.785
# Model:                            OLS   Adj. R-squared:                  0.719
# Method:                 Least Squares   F-statistic:                     11.88
# Date:                Tue, 24 Jan 2023   Prob (F-statistic):           0.000278
# Time:                        18:05:05   Log-Likelihood:                -176.05
# No. Observations:                  18   AIC:                             362.1
# Df Residuals:                      13   BIC:                             366.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ...

# %%
results_summary = tx_spouse_model_fit0.summary()
results_as_html = results_summary.tables[0].as_html()

model_df_tx = pd.read_html(results_as_html, header=0, index_col=0)[0]

model_df_tx
#.to_csv("test.csv")
#tx_spouse_model_fit0.tables
#model_df_tx['State'] ='Texas'
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                              spouse           R-squared:       0.785
# Dep. Variable:
# Model:                          OLS      Adj. R-squared:    0.719000
# Method:               Least Squares         F-statistic:   11.880000
# Date:              Tue, 24 Jan 2023  Prob (F-statistic):    0.000278
# Time:                      18:32:18      Log-Likelihood: -176.050000
# No. Observations:                18                 AIC:  362.100000
# Df Residuals:                    13                 BIC:  366.500000
# Df Model:                         4                  NaN         NaN
# Covariance Type:          nonrobust                  NaN         NaN

# %%
#results_summary = tx_spouse_model_fit0.summary()
results_as_html = results_summary.tables[1].as_html()

pd.read_html(results_as_html, header=0, index_col=0)[0]
# Out:
#                          coef    std err      t  P>|t|     [0.025     0.975]
# Intercept          68840.0000  12200.000  5.626  0.000  42400.000  95300.000
# abuse                -88.8069    321.545 -0.276  0.787   -783.462    605.848
# handgun            -2036.0080   1055.929 -1.928  0.076  -4317.205    245.189
# rape               -1107.8641    288.420 -3.841  0.002  -1730.958   -484.771
# domestic_violence  -4149.7772   2904.080 -1.429  0.177 -10400.000   2124.106

# %%
from statsmodels.graphics.regressionplots import plot_partregress_grid
fig = plt.figure(figsize=(8, 8))
plot_partregress_grid(tx_spouse_model_fit0, fig=fig)
plt.show()
# Out:
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1

# %%
fig = plt.figure(figsize=(8, 8))
sm1.graphics.plot_ccpr_grid(tx_spouse_model_fit0, fig=fig)
plt.show()

# %%
#linear regression using spouse from FBI Crime & Google Search Terms
tx_spouse_reg1 = 'spouse ~ abuse + handgun + rape'

#abuse + handgun + rape + domestic_violence

#model output
tx_spouse_model1 = sm.ols(formula = tx_spouse_reg1, data = texas)
tx_spouse_model_fit1 = tx_spouse_model1.fit()
print(tx_spouse_model_fit1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.698
# Method:                 Least Squares   F-statistic:                     14.11
# Date:                Tue, 10 Jan 2023   Prob (F-statistic):           0.000163
# Time:                        22:07:48   Log-Likelihood:                -177.36
# No. Observations:                  18   AIC:                             362.7
# Df Residuals:                      14   BIC:                             366.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    5.46e+04   7356.856      7.421      0.000    3.88e+04    7.04e+04
# ...

# %%
#linear regression using spouse from FBI Crime & Google Search Terms
tx_spouse_reg2 = 'spouse ~ abuse + handgun'

#abuse + handgun + rape + domestic_violence

#model output
tx_spouse_model2 = sm.ols(formula = tx_spouse_reg2, data = texas)
tx_spouse_model_fit2 = tx_spouse_model2.fit()
print(tx_spouse_model_fit2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.470
# Model:                            OLS   Adj. R-squared:                  0.400
# Method:                 Least Squares   F-statistic:                     6.661
# Date:                Tue, 10 Jan 2023   Prob (F-statistic):            0.00851
# Time:                        22:08:40   Log-Likelihood:                -184.17
# No. Observations:                  18   AIC:                             374.3
# Df Residuals:                      15   BIC:                             377.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   4.176e+04   9324.331      4.479      0.000    2.19e+04    6.16e+04
# ...

# %%
#linear regression using spouse from FBI Crime & Google Search Terms
tx_spouse_reg3 = 'spouse ~ abuse'

#abuse + handgun + rape + domestic_violence

#model output
tx_spouse_model3 = sm.ols(formula = tx_spouse_reg3, data = texas)
tx_spouse_model_fit3 = tx_spouse_model3.fit()
print(tx_spouse_model_fit3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.219
# Model:                            OLS   Adj. R-squared:                  0.170
# Method:                 Least Squares   F-statistic:                     4.481
# Date:                Tue, 10 Jan 2023   Prob (F-statistic):             0.0503
# Time:                        22:09:13   Log-Likelihood:                -187.67
# No. Observations:                  18   AIC:                             379.3
# Df Residuals:                      16   BIC:                             381.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.986e+04   9630.675      3.101      0.007    9448.017    5.03e+04
# ...

# %%
#linear regression using spouse from FBI Crime & Google Search Terms
tx_spouse_reg4 = 'spouse ~ handgun'

#abuse + handgun + rape + domestic_violence

#model output
tx_spouse_model4 = sm.ols(formula = tx_spouse_reg4, data = texas)
tx_spouse_model_fit4 = tx_spouse_model4.fit()
print(tx_spouse_model_fit4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.456
# Model:                            OLS   Adj. R-squared:                  0.422
# Method:                 Least Squares   F-statistic:                     13.43
# Date:                Tue, 10 Jan 2023   Prob (F-statistic):            0.00209
# Time:                        22:10:14   Log-Likelihood:                -184.40
# No. Observations:                  18   AIC:                             372.8
# Df Residuals:                      16   BIC:                             374.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3.907e+04   8128.120      4.807      0.000    2.18e+04    5.63e+04
# ...

# %%
#linear regression using spouse from FBI Crime & Google Search Terms
tx_spouse_reg5 = 'spouse ~ rape'

#abuse + handgun + rape + domestic_violence

#model output
tx_spouse_model5 = sm.ols(formula = tx_spouse_reg5, data = texas)
tx_spouse_model_fit5 = tx_spouse_model5.fit()
print(tx_spouse_model_fit5.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.665
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     31.81
# Date:                Tue, 10 Jan 2023   Prob (F-statistic):           3.69e-05
# Time:                        22:11:00   Log-Likelihood:                -180.04
# No. Observations:                  18   AIC:                             364.1
# Df Residuals:                      16   BIC:                             365.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    4.61e+04   6548.184      7.039      0.000    3.22e+04       6e+04
# ...

# %%
#linear regression using spouse from FBI Crime & Google Search Terms
tx_spouse_reg6 = 'spouse ~ domestic_violence'

#abuse + handgun + rape + domestic_violence

#model output
tx_spouse_model6 = sm.ols(formula = tx_spouse_reg6, data = texas)
tx_spouse_model_fit6 = tx_spouse_model6.fit()
print(tx_spouse_model_fit6.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                 -0.036
# Method:                 Least Squares   F-statistic:                    0.4111
# Date:                Tue, 10 Jan 2023   Prob (F-statistic):              0.531
# Time:                        22:11:41   Log-Likelihood:                -189.66
# No. Observations:                  18   AIC:                             383.3
# Df Residuals:                      16   BIC:                             385.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          2.161e+04   1.83e+04      1.178      0.256   -1.73e+04    6.05e+04
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=dbf2a01f-3e99-4593-9faf-0399a8afaf03' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
