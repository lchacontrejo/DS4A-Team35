# %% [markdown]
# ## Tennessee Linear Regression

# %%
#installing packages to read pingouin
# !pip install pingouin


#Import standard libraries
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
import pingouin
from scipy.stats import chi2_contingency
import matplotlib.colors as mcolors
import statsmodels.formula.api as sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 KB 27.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 107.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.1/973.1 KB 84.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 KB 57.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 101.8 MB/s eta 0:00:00
# ...
#   Created wheel for pingouin: filename=pingouin-0.5.3-py3-none-any.whl size=198588 sha256=ff6266af87d9b886eb477ddf39b58dd550b5f531d419887907f2f0a060842830
#   Stored in directory: /root/.cache/pip/wheels/17/f5/28/d3f6d4af74be0693f3e8994af3acbf53fe4efb48615cbbdda1
# ...

# %%
# TENNESSEE LINEAR REGRESSION


#read in tennessee data  
tennessee = pd.read_csv('data by state/tennessee.csv')

# %% [markdown]
# # Homosexual

# %%
#linear regression using homosexual from FBI Crime Data & Google Search Terms
tn_homosexual_relationship_reg0 = ' homosexual_relationship ~ abuse + handgun + rape + domestic_violence'

#model output
tn_homosexual_model0 = sm.ols(formula = tn_homosexual_relationship_reg0, data = tennessee)
tn_homosexual_model_fit0 = tn_homosexual_model0.fit()
print(tn_homosexual_model_fit0.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.571
# Model:                                 OLS   Adj. R-squared:                  0.439
# Method:                      Least Squares   F-statistic:                     4.331
# Date:                     Sat, 21 Jan 2023   Prob (F-statistic):             0.0192
# Time:                             03:47:37   Log-Likelihood:                -130.06
# No. Observations:                       18   AIC:                             270.1
# Df Residuals:                           13   BIC:                             274.6
# Df Model:                                4
# Covariance Type:                 nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
#linear regression using homosexual from FBI Crime Data & Google Search Terms
tn_homosexual_relationship_reg0 = ' homosexual_relationship ~ rape'

#model output
tn_homosexual_model0 = sm.ols(formula = tn_homosexual_relationship_reg0, data = tennessee)
tn_homosexual_model_fit0 = tn_homosexual_model0.fit()
print(tn_homosexual_model_fit0.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.539
# Model:                                 OLS   Adj. R-squared:                  0.511
# Method:                      Least Squares   F-statistic:                     18.74
# Date:                     Sat, 21 Jan 2023   Prob (F-statistic):           0.000519
# Time:                             03:48:07   Log-Likelihood:                -130.71
# No. Observations:                       18   AIC:                             265.4
# Df Residuals:                           16   BIC:                             267.2
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -575.1496    414.960     -1.386      0.185   -1454.825     304.525
# ...

# %%
#linear regression using homosexual from FBI Crime Data & Google Search Terms
tn_homosexual_relationship_reg1 = ' homosexual_relationship ~ abuse + handgun + rape'

#model output
tn_homosexual_model1 = sm.ols(formula = tn_homosexual_relationship_reg1, data = tennessee)
tn_homosexual_model_fit1 = tn_homosexual_model1.fit()
print(tn_homosexual_model_fit1.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.553
# Model:                                 OLS   Adj. R-squared:                  0.457
# Method:                      Least Squares   F-statistic:                     5.763
# Date:                     Sat, 21 Jan 2023   Prob (F-statistic):            0.00879
# Time:                             03:47:37   Log-Likelihood:                -130.45
# No. Observations:                       18   AIC:                             268.9
# Df Residuals:                           14   BIC:                             272.5
# Df Model:                                3
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -329.0678    707.131     -0.465      0.649   -1845.713    1187.577
# ...

# %%
#linear regression using homosexual from FBI Crime Data & Google Search Terms
tn_homosexual_relationship_reg2 = ' homosexual_relationship ~ abuse + handgun'

#model output
tn_homosexual_model2 = sm.ols(formula = tn_homosexual_relationship_reg2, data = tennessee)
tn_homosexual_model_fit2 = tn_homosexual_model2.fit()
print(tn_homosexual_model_fit2.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.073
# Model:                                 OLS   Adj. R-squared:                 -0.051
# Method:                      Least Squares   F-statistic:                    0.5876
# Date:                     Sat, 21 Jan 2023   Prob (F-statistic):              0.568
# Time:                             03:47:37   Log-Likelihood:                -137.01
# No. Observations:                       18   AIC:                             280.0
# Df Residuals:                           15   BIC:                             282.7
# Df Model:                                2
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    234.2496    962.487      0.243      0.811   -1817.242    2285.742
# ...

# %%
#linear regression using homosexual from FBI Crime Data & Google Search Terms
tn_homosexual_relationship_reg3 = ' homosexual_relationship ~ abuse'

#model output
tn_homosexual_model3 = sm.ols(formula = tn_homosexual_relationship_reg3, data = tennessee)
tn_homosexual_model_fit3 = tn_homosexual_model3.fit()
print(tn_homosexual_model_fit3.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.024
# Model:                                 OLS   Adj. R-squared:                 -0.037
# Method:                      Least Squares   F-statistic:                    0.3986
# Date:                     Sat, 21 Jan 2023   Prob (F-statistic):              0.537
# Time:                             03:47:37   Log-Likelihood:                -137.46
# No. Observations:                       18   AIC:                             278.9
# Df Residuals:                           16   BIC:                             280.7
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    669.3096    821.582      0.815      0.427   -1072.366    2410.985
# ...

# %%
#linear regression using homosexual from FBI Crime Data & Google Search Terms
tn_homosexual_relationship_reg4 = ' homosexual_relationship ~ handgun'

#model output
tn_homosexual_model4 = sm.ols(formula = tn_homosexual_relationship_reg4, data = tennessee)
tn_homosexual_model_fit4 = tn_homosexual_model4.fit()
print(tn_homosexual_model_fit4.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.066
# Model:                                 OLS   Adj. R-squared:                  0.007
# Method:                      Least Squares   F-statistic:                     1.124
# Date:                     Sat, 21 Jan 2023   Prob (F-statistic):              0.305
# Time:                             03:47:37   Log-Likelihood:                -137.07
# No. Observations:                       18   AIC:                             278.1
# Df Residuals:                           16   BIC:                             279.9
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    448.2452    702.884      0.638      0.533   -1041.803    1938.293
# ...

# %%
#linear regression using homosexual from FBI Crime Data & Google Search Terms
tn_homosexual_relationship_reg5 = ' homosexual_relationship ~ rape'

#model output
tn_homosexual_model5 = sm.ols(formula = tn_homosexual_relationship_reg5, data = tennessee)
tn_homosexual_model_fit5 = tn_homosexual_model5.fit()
print(tn_homosexual_model_fit5.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.539
# Model:                                 OLS   Adj. R-squared:                  0.511
# Method:                      Least Squares   F-statistic:                     18.74
# Date:                     Sat, 21 Jan 2023   Prob (F-statistic):           0.000519
# Time:                             03:47:37   Log-Likelihood:                -130.71
# No. Observations:                       18   AIC:                             265.4
# Df Residuals:                           16   BIC:                             267.2
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -575.1496    414.960     -1.386      0.185   -1454.825     304.525
# ...

# %%
#linear regression using homosexual from FBI Crime Data & Google Search Terms
tn_homosexual_relationship_reg6 = ' homosexual_relationship ~ domestic_violence'

#model output
tn_homosexual_model6 = sm.ols(formula = tn_homosexual_relationship_reg6, data = tennessee)
tn_homosexual_model_fit6 = tn_homosexual_model6.fit()
print(tn_homosexual_model_fit6.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     homosexual_relationship   R-squared:                       0.049
# Model:                                 OLS   Adj. R-squared:                 -0.011
# Method:                      Least Squares   F-statistic:                    0.8169
# Date:                     Sat, 21 Jan 2023   Prob (F-statistic):              0.379
# Time:                             03:47:37   Log-Likelihood:                -137.24
# No. Observations:                       18   AIC:                             278.5
# Df Residuals:                           16   BIC:                             280.3
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Relationship

# %%
#linear regression using relationship status from FBI Crime & Google Search Terms
tn_relationship_reg0 = 'boyfriend_girlfriend ~ abuse + handgun + rape + domestic_violence'

#abuse + handgun + rape + domestic_violence

#model output
tn_relationship_model0 = sm.ols(formula = tn_relationship_reg0, data = tennessee)
tn_relationship_model_fit0 = tn_relationship_model0.fit()
print(tn_relationship_model_fit0.summary())
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.691
# Model:                              OLS   Adj. R-squared:                  0.596
# Method:                   Least Squares   F-statistic:                     7.268
# Date:                  Sat, 21 Jan 2023   Prob (F-statistic):            0.00266
# Time:                          03:47:37   Log-Likelihood:                -161.72
# No. Observations:                    18   AIC:                             333.4
# Df Residuals:                        13   BIC:                             337.9
# Df Model:                             4
# Covariance Type:              nonrobust
# ...

# %%
#linear regression using relationship status from FBI Crime & Google Search Terms
tn_relationship_reg1 = 'boyfriend_girlfriend ~ abuse + handgun + rape'

#abuse + handgun + rape + domestic_violence

#model output
tn_relationship_model1 = sm.ols(formula = tn_relationship_reg1, data = tennessee)
tn_relationship_model_fit1 = tn_relationship_model1.fit()
print(tn_relationship_model_fit1.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.682
# Model:                              OLS   Adj. R-squared:                  0.614
# Method:                   Least Squares   F-statistic:                     10.02
# Date:                  Sat, 21 Jan 2023   Prob (F-statistic):           0.000873
# Time:                          03:47:37   Log-Likelihood:                -161.97
# No. Observations:                    18   AIC:                             331.9
# Df Residuals:                        14   BIC:                             335.5
# Df Model:                             3
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.636e+04   4074.932      4.016      0.001    7624.303    2.51e+04
# ...

# %%
#linear regression using relationship status from FBI Crime & Google Search Terms
tn_relationship_reg2 = 'boyfriend_girlfriend ~ abuse + handgun'

#abuse + handgun + rape + domestic_violence

#model output
tn_relationship_model2 = sm.ols(formula = tn_relationship_reg2, data = tennessee)
tn_relationship_model_fit2 = tn_relationship_model2.fit()
print(tn_relationship_model_fit2.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.519
# Model:                              OLS   Adj. R-squared:                  0.455
# Method:                   Least Squares   F-statistic:                     8.088
# Date:                  Sat, 21 Jan 2023   Prob (F-statistic):            0.00414
# Time:                          03:47:37   Log-Likelihood:                -165.71
# No. Observations:                    18   AIC:                             337.4
# Df Residuals:                        15   BIC:                             340.1
# Df Model:                             2
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.861e+04   4740.734      3.926      0.001    8507.059    2.87e+04
# ...

# %%
#linear regression using relationship status from FBI Crime & Google Search Terms
tn_relationship_reg3 = 'boyfriend_girlfriend ~ abuse'

#abuse + handgun + rape + domestic_violence

#model output
tn_relationship_model3 = sm.ols(formula = tn_relationship_reg3, data = tennessee)
tn_relationship_model_fit3 = tn_relationship_model3.fit()
print(tn_relationship_model_fit3.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.367
# Model:                              OLS   Adj. R-squared:                  0.328
# Method:                   Least Squares   F-statistic:                     9.295
# Date:                  Sat, 21 Jan 2023   Prob (F-statistic):            0.00766
# Time:                          03:47:37   Log-Likelihood:                -168.17
# No. Observations:                    18   AIC:                             340.3
# Df Residuals:                        16   BIC:                             342.1
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.388e+04   4523.534      5.278      0.000    1.43e+04    3.35e+04
# ...

# %%
#linear regression using relationship status from FBI Crime & Google Search Terms
tn_relationship_reg4 = 'boyfriend_girlfriend ~ handgun'

#abuse + handgun + rape + domestic_violence

#model output
tn_relationship_model4 = sm.ols(formula = tn_relationship_reg4, data = tennessee)
tn_relationship_model_fit4 = tn_relationship_model4.fit()
print(tn_relationship_model_fit4.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.304
# Model:                              OLS   Adj. R-squared:                  0.260
# Method:                   Least Squares   F-statistic:                     6.983
# Date:                  Sat, 21 Jan 2023   Prob (F-statistic):             0.0177
# Time:                          03:47:37   Log-Likelihood:                -169.03
# No. Observations:                    18   AIC:                             342.1
# Df Residuals:                        16   BIC:                             343.8
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.671e+04   4148.784      6.438      0.000    1.79e+04    3.55e+04
# ...

# %%
#linear regression using relationship status from FBI Crime & Google Search Terms
tn_relationship_reg5 = 'boyfriend_girlfriend ~ rape'

#abuse + handgun + rape + domestic_violence

#model output
tn_relationship_model5 = sm.ols(formula = tn_relationship_reg5, data = tennessee)
tn_relationship_model_fit5 = tn_relationship_model5.fit()
print(tn_relationship_model_fit5.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.451
# Model:                              OLS   Adj. R-squared:                  0.417
# Method:                   Least Squares   F-statistic:                     13.17
# Date:                  Sat, 21 Jan 2023   Prob (F-statistic):            0.00226
# Time:                          03:47:37   Log-Likelihood:                -166.89
# No. Observations:                    18   AIC:                             337.8
# Df Residuals:                        16   BIC:                             339.6
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.651e+04   3096.791      8.562      0.000    1.99e+04    3.31e+04
# ...

# %%
#linear regression using relationship status from FBI Crime & Google Search Terms
tn_relationship_reg6 = 'boyfriend_girlfriend ~ domestic_violence'

#abuse + handgun + rape + domestic_violence

#model output
tn_relationship_model6 = sm.ols(formula = tn_relationship_reg6, data = tennessee)
tn_relationship_model_fit6 = tn_relationship_model6.fit()
print(tn_relationship_model_fit6.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     boyfriend_girlfriend   R-squared:                       0.100
# Model:                              OLS   Adj. R-squared:                  0.044
# Method:                   Least Squares   F-statistic:                     1.777
# Date:                  Sat, 21 Jan 2023   Prob (F-statistic):              0.201
# Time:                          03:47:37   Log-Likelihood:                -171.34
# No. Observations:                    18   AIC:                             346.7
# Df Residuals:                        16   BIC:                             348.5
# Df Model:                             1
# Covariance Type:              nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          3.119e+04   4806.061      6.491      0.000     2.1e+04    4.14e+04
# ...

# %% [markdown]
# # Exspouse

# %%
#linear regression using ex-spouse from FBI Crime & Google Search Terms
tn_exspouse_reg0 = ' ex_spouse ~ abuse + handgun + rape + domestic_violence'

#abuse + handgun + rape + domestic_violence

#model output
tn_exspouse_model0 = sm.ols(formula = tn_exspouse_reg0, data = tennessee)
tn_exspouse_model_fit0 = tn_exspouse_model0.fit()
print(tn_exspouse_model_fit0.summary())
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.891
# Model:                            OLS   Adj. R-squared:                  0.857
# Method:                 Least Squares   F-statistic:                     26.52
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):           3.80e-06
# Time:                        03:47:37   Log-Likelihood:                -113.83
# No. Observations:                  18   AIC:                             237.7
# Df Residuals:                      13   BIC:                             242.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ...

# %%
#linear regression using ex-spouse from FBI Crime & Google Search Terms
tn_exspouse_reg1 = ' ex_spouse ~ abuse + handgun + rape'

#abuse + handgun + rape + domestic_violence

#model output
tn_exspouse_model1 = sm.ols(formula = tn_exspouse_reg1, data = tennessee)
tn_exspouse_model_fit1 = tn_exspouse_model1.fit()
print(tn_exspouse_model_fit1.summary())
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.889
# Model:                            OLS   Adj. R-squared:                  0.865
# Method:                 Least Squares   F-statistic:                     37.40
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):           6.17e-07
# Time:                        03:47:37   Log-Likelihood:                -113.97
# No. Observations:                  18   AIC:                             235.9
# Df Residuals:                      14   BIC:                             239.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ...

# %%
#linear regression using ex-spouse from FBI Crime & Google Search Terms
tn_exspouse_reg2 = ' ex_spouse ~ abuse + handgun'

#abuse + handgun + rape + domestic_violence

#model output
tn_exspouse_model2 = sm.ols(formula = tn_exspouse_reg2, data = tennessee)
tn_exspouse_model_fit2 = tn_exspouse_model2.fit()
print(tn_exspouse_model_fit2.summary())
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.889
# Model:                            OLS   Adj. R-squared:                  0.874
# Method:                 Least Squares   F-statistic:                     60.01
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):           6.96e-08
# Time:                        03:47:37   Log-Likelihood:                -113.98
# No. Observations:                  18   AIC:                             234.0
# Df Residuals:                      15   BIC:                             236.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %%
#linear regression using ex-spouse from FBI Crime & Google Search Terms
tn_exspouse_reg3 = ' ex_spouse ~ abuse'

#abuse + handgun + rape + domestic_violence

#model output
tn_exspouse_model3 = sm.ols(formula = tn_exspouse_reg3, data = tennessee)
tn_exspouse_model_fit3 = tn_exspouse_model3.fit()
print(tn_exspouse_model_fit3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.811
# Model:                            OLS   Adj. R-squared:                  0.799
# Method:                 Least Squares   F-statistic:                     68.59
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):           3.53e-07
# Time:                        03:47:38   Log-Likelihood:                -118.77
# No. Observations:                  18   AIC:                             241.5
# Df Residuals:                      16   BIC:                             243.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -144.3772    290.862     -0.496      0.626    -760.977     472.222
# ...

# %%
#linear regression using ex-spouse from FBI Crime & Google Search Terms
tn_exspouse_reg4 = ' ex_spouse ~ handgun'

#abuse + handgun + rape + domestic_violence

#model output
tn_exspouse_model4 = sm.ols(formula = tn_exspouse_reg4, data = tennessee)
tn_exspouse_model_fit4 = tn_exspouse_model4.fit()
print(tn_exspouse_model_fit4.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.285
# Model:                            OLS   Adj. R-squared:                  0.240
# Method:                 Least Squares   F-statistic:                     6.369
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):             0.0226
# Time:                        03:47:38   Log-Likelihood:                -130.74
# No. Observations:                  18   AIC:                             265.5
# Df Residuals:                      16   BIC:                             267.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1007.5898    494.499      2.038      0.058     -40.701    2055.881
# ...

# %%
#linear regression using ex-spouse from FBI Crime & Google Search Terms
tn_exspouse_reg5 = ' ex_spouse ~ rape'

#abuse + handgun + rape + domestic_violence

#model output
tn_exspouse_model5 = sm.ols(formula = tn_exspouse_reg5, data = tennessee)
tn_exspouse_model_fit5 = tn_exspouse_model5.fit()
print(tn_exspouse_model_fit5.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.130
# Model:                            OLS   Adj. R-squared:                  0.076
# Method:                 Least Squares   F-statistic:                     2.395
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):              0.141
# Time:                        03:47:38   Log-Likelihood:                -132.50
# No. Observations:                  18   AIC:                             269.0
# Df Residuals:                      16   BIC:                             270.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1542.1467    458.512      3.363      0.004     570.144    2514.150
# ...

# %%
#linear regression using ex-spouse from FBI Crime & Google Search Terms
tn_exspouse_reg6 = ' ex_spouse ~ domestic_violence'

#abuse + handgun + rape + domestic_violence

#model output
tn_exspouse_model6 = sm.ols(formula = tn_exspouse_reg6, data = tennessee)
tn_exspouse_model_fit6 = tn_exspouse_model6.fit()
print(tn_exspouse_model_fit6.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              ex_spouse   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     1.232
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):              0.283
# Time:                        03:47:38   Log-Likelihood:                -133.09
# No. Observations:                  18   AIC:                             270.2
# Df Residuals:                      16   BIC:                             272.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          1608.6471    573.998      2.803      0.013     391.825    2825.469
# ...

# %% [markdown]
# # Spouse

# %%
#linear regression using spouse from FBI Crime & Google Search Terms
tn_spouse_reg0 = 'spouse ~ abuse + handgun + rape + domestic_violence'

#model output
tn_spouse_model0 = sm.ols(formula = tn_spouse_reg0, data = tennessee)
tn_spouse_model_fit0 = tn_spouse_model0.fit()
print(tn_spouse_model_fit0.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     44.91
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):           1.73e-07
# Time:                        03:47:38   Log-Likelihood:                -142.67
# No. Observations:                  18   AIC:                             295.3
# Df Residuals:                      13   BIC:                             299.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept         -2544.1589   1602.812     -1.587      0.136   -6006.824     918.506
# ...

# %%
#linear regression using spouse from FBI Crime & Google Search Terms
tn_spouse_reg1 = 'spouse ~ abuse + handgun + rape'

#model output
tn_spouse_model1 = sm.ols(formula = tn_spouse_reg1, data = tennessee)
tn_spouse_model_fit1 = tn_spouse_model1.fit()
print(tn_spouse_model_fit1.summary())
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.931
# Model:                            OLS   Adj. R-squared:                  0.916
# Method:                 Least Squares   F-statistic:                     62.85
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):           2.29e-08
# Time:                        03:47:38   Log-Likelihood:                -142.88
# No. Observations:                  18   AIC:                             293.8
# Df Residuals:                      14   BIC:                             297.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ...

# %%
#linear regression using spouse from FBI Crime & Google Search Terms
tn_spouse_reg2 = 'spouse ~ abuse + handgun'

#model output
tn_spouse_model2 = sm.ols(formula = tn_spouse_reg2, data = tennessee)
tn_spouse_model_fit2 = tn_spouse_model2.fit()
print(tn_spouse_model_fit2.summary())
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.904
# Model:                            OLS   Adj. R-squared:                  0.892
# Method:                 Least Squares   F-statistic:                     70.86
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):           2.28e-08
# Time:                        03:47:38   Log-Likelihood:                -145.81
# No. Observations:                  18   AIC:                             297.6
# Df Residuals:                      15   BIC:                             300.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...

# %%
#linear regression using spouse from FBI Crime & Google Search Terms
tn_spouse_reg3 = 'spouse ~ abuse'

#model output
tn_spouse_model3 = sm.ols(formula = tn_spouse_reg3, data = tennessee)
tn_spouse_model_fit3 = tn_spouse_model3.fit()
print(tn_spouse_model_fit3.summary())
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.868
# Model:                            OLS   Adj. R-squared:                  0.860
# Method:                 Least Squares   F-statistic:                     105.0
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):           1.95e-08
# Time:                        03:47:38   Log-Likelihood:                -148.72
# No. Observations:                  18   AIC:                             301.4
# Df Residuals:                      16   BIC:                             303.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
#linear regression using spouse from FBI Crime & Google Search Terms
tn_spouse_reg4 = 'spouse ~ handgun'

#model output
tn_spouse_model4 = sm.ols(formula = tn_spouse_reg4, data = tennessee)
tn_spouse_model_fit4 = tn_spouse_model4.fit()
print(tn_spouse_model_fit4.summary())
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.210
# Model:                            OLS   Adj. R-squared:                  0.161
# Method:                 Least Squares   F-statistic:                     4.257
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):             0.0557
# Time:                        03:47:38   Log-Likelihood:                -164.81
# No. Observations:                  18   AIC:                             333.6
# Df Residuals:                      16   BIC:                             335.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
#linear regression using spouse from FBI Crime & Google Search Terms
tn_spouse_reg5 = 'spouse ~ rape'

#model output
tn_spouse_model5 = sm.ols(formula = tn_spouse_reg5, data = tennessee)
tn_spouse_model_fit5 = tn_spouse_model5.fit()
print(tn_spouse_model_fit5.summary())
# Out:
# /shared-libs/python3.9/py/lib/python3.9/site-packages/scipy/stats/_stats_py.py:1772: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                 -0.029
# Method:                 Least Squares   F-statistic:                    0.5263
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):              0.479
# Time:                        03:47:38   Log-Likelihood:                -166.64
# No. Observations:                  18   AIC:                             337.3
# Df Residuals:                      16   BIC:                             339.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
#linear regression using spouse from FBI Crime & Google Search Terms
tn_spouse_reg6 = 'spouse ~ domestic_violence'

#model output
tn_spouse_model6 = sm.ols(formula = tn_spouse_reg6, data = tennessee)
tn_spouse_model_fit6 = tn_spouse_model6.fit()
print(tn_spouse_model_fit6.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 spouse   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                 -0.034
# Method:                 Least Squares   F-statistic:                    0.4386
# Date:                Sat, 21 Jan 2023   Prob (F-statistic):              0.517
# Time:                        03:47:38   Log-Likelihood:                -166.69
# No. Observations:                  18   AIC:                             337.4
# Df Residuals:                      16   BIC:                             339.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          1.145e+04   3711.179      3.084      0.007    3578.571    1.93e+04
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=dbf2a01f-3e99-4593-9faf-0399a8afaf03' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
